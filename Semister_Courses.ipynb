# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharmilazaman/AI-Lab/blob/main/Semister_Courses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = []
choice = 'random'

def line():
    print('---------------------------')

def show_course():
    line()
    print('Spring21')
    line()
    print('1. Enroll Course')
    print('2. Remove Course')
    print('3. View Courses')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice != '4':
    choice = show_course()
    if choice == '1':
        item = input('Enter Your Course: ')
        data.append(item)
        print('Course', item, 'added')
    elif choice == '2':
        item = input('Which Course you want to remove? ')
        if item in data:
            data.remove(item)
            print('Removed item', item)
        else:
            print('Could not find Course', item)
    elif choice == '3':
        print('List of the courses:')
        for item in data:
            print(item)
    elif choice == '4':
        print('Thank You!')
    else:
        print('Please enter one of 1, 2, 3 or 4')
# Out:
# ---------------------------
# Spring21
# ---------------------------
# 1. Enroll Course
# 2. Remove Course
# 3. View Courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Enter Your Course: Artificial Intelligence
# Course Artificial Intelligence added
# ---------------------------
# Spring21
# ---------------------------
# 1. Enroll Course
# 2. Remove Course
# 3. View Courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Enter Your Course: Simulation
# Course Simulation  added
# ---------------------------
# Spring21
# ---------------------------
# 1. Enroll Course
# 2. Remove Course
# 3. View Courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Enter Your Course: Web Engineering
# Course Web Engineering added
# ---------------------------
# Spring21
# ---------------------------
# 1. Enroll Course
# 2. Remove Course
# 3. View Courses
# 4. Exit
# ---------------------------
# Enter your choice: 3
# List of the courses:
# ...
